# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt

# %%
API_KEY = ''

# %%
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&symbol=IBM&apikey=demo'
r = requests.get(url)
data = r.json()

# %%
time = data['Time Series (Daily)']
df = pd.DataFrame.from_dict(time, orient='index',dtype=float)
df
# Out:
#             1. open   2. high    3. low  4. close  5. adjusted close  \
# 2025-02-28  250.855  252.8099  246.5400    252.44         252.440000
# 2025-02-27  255.220  257.6300  253.0500    253.23         253.230000
# 2025-02-26  258.100  258.3250  254.4104    255.84         255.840000
# 2025-02-25  261.080  263.4800  256.7700    257.75         257.750000
# 2025-02-24  261.500  263.8450  259.5800    261.87         261.870000
# ...             ...       ...       ...       ...                ...
# 2024-10-10  235.100  235.8300  231.8100    233.02         229.650438
# 2024-10-09  229.200  234.9500  228.5000    234.30         230.911929
# 2024-10-08  228.110  229.3450  227.0401    228.62         225.314064
# 2024-10-07  225.380  227.6700  225.0200    227.12         223.835754
# 2024-10-04  223.750  226.0800  223.2700    226.00         222.731950
#
#             6. volume  7. dividend amount  8. split coefficient
# 2025-02-28  7988809.0                 0.0                   1.0
# ...

# %%
df.columns = ['open', 'high', 'low', 'close', 'adjusted close', 'volume', 'dividend amount', 'split coefficient']
df
# Out:
#                open      high       low   close  adjusted close     volume  \
# 2025-02-28  250.855  252.8099  246.5400  252.44      252.440000  7988809.0
# 2025-02-27  255.220  257.6300  253.0500  253.23      253.230000  3402234.0
# 2025-02-26  258.100  258.3250  254.4104  255.84      255.840000  3460124.0
# 2025-02-25  261.080  263.4800  256.7700  257.75      257.750000  6292487.0
# 2025-02-24  261.500  263.8450  259.5800  261.87      261.870000  4398107.0
# ...             ...       ...       ...     ...             ...        ...
# 2024-10-10  235.100  235.8300  231.8100  233.02      229.650438  3142031.0
# 2024-10-09  229.200  234.9500  228.5000  234.30      230.911929  5083566.0
# 2024-10-08  228.110  229.3450  227.0401  228.62      225.314064  3245342.0
# 2024-10-07  225.380  227.6700  225.0200  227.12      223.835754  3457952.0
# 2024-10-04  223.750  226.0800  223.2700  226.00      222.731950  3554328.0
#
#             dividend amount  split coefficient
# ...

# %%
df.index.name = 'date'
df
# Out:
#                open      high       low   close  adjusted close     volume  \
# date
# 2025-02-28  250.855  252.8099  246.5400  252.44      252.440000  7988809.0
# 2025-02-27  255.220  257.6300  253.0500  253.23      253.230000  3402234.0
# 2025-02-26  258.100  258.3250  254.4104  255.84      255.840000  3460124.0
# 2025-02-25  261.080  263.4800  256.7700  257.75      257.750000  6292487.0
# 2025-02-24  261.500  263.8450  259.5800  261.87      261.870000  4398107.0
# ...             ...       ...       ...     ...             ...        ...
# 2024-10-10  235.100  235.8300  231.8100  233.02      229.650438  3142031.0
# 2024-10-09  229.200  234.9500  228.5000  234.30      230.911929  5083566.0
# 2024-10-08  228.110  229.3450  227.0401  228.62      225.314064  3245342.0
# 2024-10-07  225.380  227.6700  225.0200  227.12      223.835754  3457952.0
# 2024-10-04  223.750  226.0800  223.2700  226.00      222.731950  3554328.0
#
#             dividend amount  split coefficient
# date
# ...

# %%
# plot the open and close values
fig, ax = plt.subplots(figsize=(10,8))
ax.plot(df['open'], label='open')
ax.plot(df['close'], label='close')
ax.legend()
plt.show()
